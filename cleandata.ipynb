# %%
import pandas as pd
# Out:
# /var/folders/bw/x8pm_mm52673v9zqn742_jhw0000gn/T/ipykernel_11595/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
total_data= pd.read_csv("Wimbledon_featured_matches.csv")

# %%
Carlos_player1= total_data.loc[total_data["player1"]=="Carlos Alcaraz"]
Carlos_player2= total_data.loc[total_data["player2"]=="Carlos Alcaraz"]
Carlos_Alcaraz = pd.concat([Carlos_player1,Carlos_player2],ignore_index=True)
Carlos_Alcaraz
#it seeems Carlos only appear as the first player
# Out:
#                  match_id         player1         player2 elapsed_time  \
# 0     2023-wimbledon-1301  Carlos Alcaraz   Nicolas Jarry     00:00:00
# 1     2023-wimbledon-1301  Carlos Alcaraz   Nicolas Jarry     00:00:38
# 2     2023-wimbledon-1301  Carlos Alcaraz   Nicolas Jarry     00:01:01
# 3     2023-wimbledon-1301  Carlos Alcaraz   Nicolas Jarry     00:01:31
# 4     2023-wimbledon-1301  Carlos Alcaraz   Nicolas Jarry     00:02:21
# ...                   ...             ...             ...          ...
# 1202  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:39:58
# 1203  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:40:43
# 1204  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:41:20
# 1205  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:41:52
# 1206  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:42:27
#
#       set_no  game_no  point_no  p1_sets  p2_sets  p1_games  ...  \
# ...

# %%
Novac_player1= total_data.loc[total_data["player1"]=="Novak Djokovic"]
Novac_player2= total_data.loc[total_data["player2"]=="Novak Djokovic"]
Novak_Djokovic = pd.concat([Novac_player1,Novac_player2],ignore_index=True)
Novak_Djokovic

#it seeems Novak only appear as the second player
# Out:
#                  match_id         player1         player2 elapsed_time  \
# 0     2023-wimbledon-1316   Stan Wawrinka  Novak Djokovic     00:00:00
# 1     2023-wimbledon-1316   Stan Wawrinka  Novak Djokovic     00:00:35
# 2     2023-wimbledon-1316   Stan Wawrinka  Novak Djokovic     00:00:56
# 3     2023-wimbledon-1316   Stan Wawrinka  Novak Djokovic     00:01:24
# 4     2023-wimbledon-1316   Stan Wawrinka  Novak Djokovic     00:01:48
# ...                   ...             ...             ...          ...
# 1186  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:39:58
# 1187  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:40:43
# 1188  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:41:20
# 1189  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:41:52
# 1190  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     04:42:27
#
#       set_no  game_no  point_no  p1_sets  p2_sets  p1_games  ...  \
# ...

# %%
Carlos_Alcaraz.to_csv(path_or_buf="/Users/nataliehu/Desktop/MCM/Carlos_Alcaraz.csv")

# %%
Novak_Djokovic.to_csv(path_or_buf="/Users/nataliehu/Desktop/MCM/Novak_Djokovic.csv")
